# %% [markdown]
# <a href="https://colab.research.google.com/github/mebkdas/Python/blob/master/SVMClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import of library
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
#Import and working with the datasets
iris = datasets.load_iris()
X = iris.data[:, :2]
Y = iris.target

# %%
#Create an instance of SVM and try to fir the data
C = 1.0 #Regularization parameter of SVM
svc = svm.SVC(kernel='rbf', C = 1, gamma='auto').fit(X,Y)

# %%
#Plotting of graph
x_min, x_max = X[:,0].min()-1,X[:,0].max()-1
y_min, y_max = X[:,1].min()-1,X[:,1].max()-1
h = (x_max/x_min)/100
xx , yy = np.meshgrid(np.arange(x_min,x_max,h), np.arange(y_min,y_max,h))

# %%
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)



plt.scatter(X[:, 0],X[:, 1], c=Y ,cmap = plt.cm.Paired)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Wridth')
plt.xlim(xx.min(),xx.max())
plt.title('SVM Implementation')
plt.show()
